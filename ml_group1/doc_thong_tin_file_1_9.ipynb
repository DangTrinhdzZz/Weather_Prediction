# %%
import pandas as pd

# %%
df = pd.read_csv('data/New_X_train_sel.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Columns: 256 entries, tempmax to rain_intensity_roll_mean_5
# dtypes: float64(225), int64(29), object(2)
# memory usage: 1.7+ MB
# None
